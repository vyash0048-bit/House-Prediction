# %%
import pandas as pd
from data_profiling import ProfileReport

# Load dataset
df = pd.read_csv("../data/processed/gurgaon_properties_cleaned_v2.csv").drop_duplicates()

# Create report
profile = ProfileReport(
    df,
    title="Pandas Profiling Report",
    explorative=True
)

# Save report
profile.to_file("output_report.html")
# Out:
# 100%|██████████| 23/23 [00:00<00:00, 31.65it/s]1<00:00, 30.67it/s, Describe variable: luxury_score]
# Summarize dataset: 100%|██████████| 133/133 [00:25<00:00,  5.26it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:12<00:00, 12.24s/it]
# Render HTML: 100%|██████████| 1/1 [00:02<00:00,  2.14s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 19.37it/s]

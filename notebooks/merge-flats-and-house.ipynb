# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('../data/processed/flats_cleaned.csv')
houses = pd.read_csv('../data/processed/house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                property_name property_type  \
# 0            3 BHK Flat in Sector 79 Gurgaon          flat
# 1           3 BHK Flat in Sector 102 Gurgaon          flat
# 2            4 BHK Flat in Sector 79 Gurgaon          flat
# 3            3 BHK Flat in Sector 89 Gurgaon          flat
# 4  4 Bedroom House for sale in Subhash Nagar         house
#
#                 society  price  price_per_sqft   area  \
# 0    mapsko mount ville    NaN          8557.0    NaN
# 1  emaar gurgaon greens    NaN          8606.0    NaN
# 2        bestech altura    NaN          9532.0    NaN
# 3          tulip petals    NaN         10000.0    NaN
# 4           independent    0.9         13333.0  675.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 1490(138.43 sq.m.)Carpet a...        3         3
# 1  Super Built up area 1650(153.29 sq.m.)Carpet a...        3         3
# 2                 Built Up area: 2675 (248.52 sq.m.)        4         5
# 3                Super Built up area 1550(144 sq.m.)        3         2
# 4                   Built Up area: 675 (62.71 sq.m.)        4         4
#
#   balcony additionalRoom                                            address  \
# 0       3     study room     Sector-79, Sector 79 Gurgaon, Gurgaon, Haryana
# 1       3   servant room  Multiple Options Available, Sector 102 Gurgaon...
# 2       2   servant room                Sector 79 Gurgaon, Gurgaon, Haryana
# 3       3     store room                Sector 89 Gurgaon, Gurgaon, Haryana
# 4       0  not available  Subhash Nagar, Sector 12a, Subhash Nagar, Gurg...
#
#    floorNum facing     agePossession  \
# 0      16.0  South   1 to 5 Year Old
# 1       7.0   East   1 to 5 Year Old
# 2       4.0   East   0 to 1 Year Old
# 3       6.0   East  5 to 10 Year Old
# 4       2.0    NaN         undefined
#
#                                      nearbyLocations  \
# 0  ['Huda Metro Station (Gurugram)', 'Sapphire 83...
# 1  ['JMS Marine Square Mall', 'Dwarka Expressway'...
# 2  ['Sapphire 83 Mall', 'NH -8', 'Golf Course Ext...
# 3  ['IRIS Broadway Mall', 'Pataudi Road', 'Dwarka...
# 4                                                NaN
#
#                                          description  \
# 0  1490 sqft 3 bhk 3 bathroom semi furnished apar...
# 1  High roi investment - Unused luxury 3bhk on dw...
# 2  4 bhk with servant room on the fastest develop...
# 3  Park facing unit, east facing balconies, cover...
# 4  Best in class property available at subhash na...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Li...
# 1                                                NaN
# 2  ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 3  ['3 Wardrobe', '6 Fan', '1 Exhaust Fan', '2 Ge...
# 4  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 1  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 2  ['Security / Fire Alarm', 'Intercom Facility',...
# 3  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 4                                                NaN
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction5 out of...
# 1  ['Green Area5 out of 5', 'Construction4 out of...
# 2  ['Environment4 out of 5', 'Lifestyle3 out of 5...
# 3  ['Green Area5 out of 5', 'Amenities4 out of 5'...
# 4  ['Environment3.5 out of 5', 'Lifestyle4.5 out ...

# %%
df.to_csv('../data/processed/gurgaon_properties.csv',index=False)

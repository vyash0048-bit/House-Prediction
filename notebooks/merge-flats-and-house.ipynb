# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('../data/processed/flats_cleaned.csv')
houses = pd.read_csv('../data/processed/house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                       property_name property_type  \
# 0  3 BHK Flat in Sector 107 Gurgaon          flat
# 1   2 BHK Flat in Sector 95 Gurgaon          flat
# 2   3 BHK Flat in Sector 63 Gurgaon          flat
# 3   3 BHK Flat in Sector 83 Gurgaon          flat
# 4               2 BHK Flat in Sohna          flat
#
#                        society  price  price_per_sqft   area  \
# 0      signature global solera   0.50          7751.0  645.0
# 1         sidhartha ncr greens   0.56          5656.0  990.0
# 2  adani brahma samsara vilasa    NaN         16666.0    NaN
# 3           emaar palm gardens    NaN          9263.0    NaN
# 4       breez global hill view   0.32          5776.0  554.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                     Carpet area: 645 (59.92 sq.m.)        3         2
# 1               Super Built up area 990(91.97 sq.m.)        2         2
# 2                   Carpet area: 1800 (167.23 sq.m.)        3         3
# 3  Super Built up area 1900(176.52 sq.m.)Built Up...        3         3
# 4                     Carpet area: 554 (51.47 sq.m.)        2         2
#
#   balcony additionalRoom                                   address  floorNum  \
# 0       2         others      Sector 107 Gurgaon, Gurgaon, Haryana       6.0
# 1       3  not available       Sector 95 Gurgaon, Gurgaon, Haryana      13.0
# 2       3  not available       Sector 63 Gurgaon, Gurgaon, Haryana       3.0
# 3       3   servant room  806, Sector 83 Gurgaon, Gurgaon, Haryana       5.0
# 4       2  not available             1905, Sohna, Gurgaon, Haryana      19.0
#
#        facing    agePossession  \
# 0  South-East  1 to 5 Year Old
# 1         NaN  0 to 1 Year Old
# 2        East  0 to 1 Year Old
# 3  South-East  1 to 5 Year Old
# 4       North  1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Gurgaon Dreamz Mall', 'Dwarka Expressway', "...
# 1  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# 2  ['Rapid Metro Station Sector 56', 'Paras Trini...
# 3  ["V'Lante Mall", 'NH 48 Gurugram', 'iGrow Mont...
# 4  ['Huda City Centre', 'Omaxe City Centre', 'Nin...
#
#                                          description  \
# 0  This beautiful 3 bhk flat in sector 107 gurgao...
# 1  Residential apartment for sell.The property co...
# 2  New construction. Ready to move. Park facing unit
# 3  This 3 bhk flat is located in emaar palm garde...
# 4  Sohna is a peripheral area on the southern sid...
#
#                                       furnishDetails  \
# 0                                                NaN
# 1                                                 []
# 2  ['1 Fan', '1 Light', '1 AC', '1 Modular Kitche...
# 3  ['3 Wardrobe', '10 Fan', '1 Exhaust Fan', '3 G...
# 4  ['2 Wardrobe', '2 Bed', '1 Water Purifier', '4...
#
#                                             features  \
# 0           ['Intercom Facility', 'Lift(s)', 'Park']
# 1  ['Power Back-up', 'Lift(s)', 'Park', 'Piped-gas']
# 2  ['Lift(s)', 'Park', 'Piped-gas', 'Natural Ligh...
# 3  ['Centrally Air Conditioned', 'Water purifier'...
# 4  ['Power Back-up', 'Lift(s)', 'Maintenance Staf...
#
#                                               rating
# 0  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 1  ['Green Area4 out of 5', 'Construction5 out of...
# 2                                                NaN
# 3  ['Green Area5 out of 5', 'Construction4 out of...
# 4  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
df.to_csv('../data/processed/gurgaon_properties.csv',index=False)
